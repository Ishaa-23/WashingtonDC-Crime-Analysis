# %%
import pandas as pd
df=pd.read_excel('Dataset.xlsx')
df.head()
# Out:
#   ANC   LATITUDE                                  BLOCK offensegroup  \
# 0  6E  38.903732         100 - 199 block of l street ne     property
# 1  2C  38.903743         18th street nw and l street nw     property
# 2  1B  38.917236     2000 - 2099 block of 8th street nw     property
# 3  5D  38.909405     1300 - 1399 block of 5th street ne     property
# 4  1D  38.930801  1600 - 1665 block of lamont street nw     property
#
#                        location sector         YBLOCK  METHOD       CCN  \
# 0  38.9037316022,-77.0047283051    5D1  137319.550000  others  25002077
# 1  38.9037432394,-77.0416730027    2D3  137321.656253  others  25008226
# 2   38.917236462,-77.0229457261    3D2  138818.940000  others  25013256
# 3  38.9094049494,-76.9975459006    5D1  137949.330000  others  25001526
# 4  38.9308014266,-77.0373827045    3D1  140325.180000  others  25002498
#
#                  END_DATE  ...  DISTRICT         XBLOCK  YEAR  \
# ...

# %%
print(df.columns)
# Out:
# Index(['ANC', 'LATITUDE', 'BLOCK', 'offensegroup', 'location', 'sector',
#        'YBLOCK', 'METHOD', 'CCN', 'END_DATE', 'LONGITUDE', 'offense-text',
#        'NEIGHBORHOOD_CLUSTER', 'SHIFT', 'PSA', 'CENSUS_TRACT', 'WARD', 'BID',
#        'OCTO_RECORD_ID', 'DISTRICT', 'XBLOCK', 'YEAR', 'REPORT_DAT',
#        'ucr-rank', 'offensekey', 'START_DATE', 'VOTING_PRECINCT', 'OFFENSE',
#        'BLOCK_GROUP'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ANC                      object
# LATITUDE                float64
# BLOCK                    object
# offensegroup             object
# location                 object
# sector                   object
# YBLOCK                  float64
# METHOD                   object
# CCN                       int64
# END_DATE                 object
# LONGITUDE               float64
# offense-text             object
# NEIGHBORHOOD_CLUSTER     object
# SHIFT                    object
# PSA                     float64
# CENSUS_TRACT            float64
# WARD                    float64
# BID                      object
# OCTO_RECORD_ID          float64
# DISTRICT                float64
# XBLOCK                  float64
# YEAR                      int64
# REPORT_DAT               object
# ucr-rank                  int64
# offensekey               object
# START_DATE               object
# VOTING_PRECINCT          object
# OFFENSE                  object
# BLOCK_GROUP              object
# ...

# %%
df.isna().sum()
# Out:
# ANC                        1
# LATITUDE                   0
# BLOCK                      0
# offensegroup               0
# location                   0
# sector                     8
# YBLOCK                     0
# METHOD                     0
# CCN                        0
# END_DATE                 284
# LONGITUDE                  0
# offense-text               0
# NEIGHBORHOOD_CLUSTER       1
# SHIFT                      0
# PSA                        8
# CENSUS_TRACT               4
# WARD                       1
# BID                     3181
# OCTO_RECORD_ID          3867
# DISTRICT                   8
# XBLOCK                     0
# YEAR                       0
# REPORT_DAT                 0
# ucr-rank                   0
# offensekey                 0
# START_DATE                 1
# VOTING_PRECINCT            1
# OFFENSE                    0
# BLOCK_GROUP                4
# dtype: int64

# %%
df['END_DATE']=pd.to_datetime(df['END_DATE'])
df['REPORT_DAT']=pd.to_datetime(df['REPORT_DAT'])
df['START_DATE']=pd.to_datetime(df['START_DATE'])
df.dtypes
# Out:
# C:\Users\ishaa\AppData\Local\Temp\ipykernel_7924\45176835.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['REPORT_DAT']=pd.to_datetime(df['REPORT_DAT'])
# C:\Users\ishaa\AppData\Local\Temp\ipykernel_7924\45176835.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['START_DATE']=pd.to_datetime(df['START_DATE'])
# ANC                             object
# LATITUDE                       float64
# BLOCK                           object
# offensegroup                    object
# location                        object
# sector                          object
# YBLOCK                         float64
# METHOD                          object
# CCN                              int64
# ...

# %%
df.isna().sum()
# Out:
# ANC                        1
# LATITUDE                   0
# BLOCK                      0
# offensegroup               0
# location                   0
# sector                     8
# YBLOCK                     0
# METHOD                     0
# CCN                        0
# END_DATE                 284
# LONGITUDE                  0
# offense-text               0
# NEIGHBORHOOD_CLUSTER       1
# SHIFT                      0
# PSA                        8
# CENSUS_TRACT               4
# WARD                       1
# BID                     3181
# OCTO_RECORD_ID          3867
# DISTRICT                   8
# XBLOCK                     0
# YEAR                       0
# REPORT_DAT                 0
# ucr-rank                   0
# offensekey                 0
# START_DATE                 1
# VOTING_PRECINCT            1
# OFFENSE                    0
# BLOCK_GROUP                4
# dtype: int64

# %%
df.drop(columns=['OCTO_RECORD_ID','BID'],inplace=True)
df.isna().sum()
# Out:
# ANC                       1
# LATITUDE                  0
# BLOCK                     0
# offensegroup              0
# location                  0
# sector                    8
# YBLOCK                    0
# METHOD                    0
# CCN                       0
# END_DATE                284
# LONGITUDE                 0
# offense-text              0
# NEIGHBORHOOD_CLUSTER      1
# SHIFT                     0
# PSA                       8
# CENSUS_TRACT              4
# WARD                      1
# DISTRICT                  8
# XBLOCK                    0
# YEAR                      0
# REPORT_DAT                0
# ucr-rank                  0
# offensekey                0
# START_DATE                1
# VOTING_PRECINCT           1
# OFFENSE                   0
# BLOCK_GROUP               4
# dtype: int64

# %%
df['ANC'].fillna(df['ANC'].mode()[0],inplace=True)
df.isna().sum()
# Out:
# C:\Users\ishaa\AppData\Local\Temp\ipykernel_7924\2884889841.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ANC'].fillna(df['ANC'].mode()[0],inplace=True)
# ANC                       0
# LATITUDE                  0
# BLOCK                     0
# offensegroup              0
# location                  0
# sector                    8
# YBLOCK                    0
# METHOD                    0
# CCN                       0
# END_DATE                284
# LONGITUDE                 0
# ...

# %%
df['WARD'].fillna(df['WARD'].mode()[0],inplace=True)
df['VOTING_PRECINCT'].fillna(df['VOTING_PRECINCT'].mode()[0],inplace=True)
df['NEIGHBORHOOD_CLUSTER'].fillna('Unknown',inplace=True)
df['BLOCK_GROUP'].fillna('Unknown',inplace=True)
df['DISTRICT'].fillna('Unknown',inplace=True)
df['CENSUS_TRACT'].fillna('Unknown',inplace=True)
df['PSA'].fillna('Unknown',inplace=True)
df['sector'].fillna('Unknown',inplace=True)
df.isna().sum()
# Out:
# C:\Users\ishaa\AppData\Local\Temp\ipykernel_7924\1962741249.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['WARD'].fillna(df['WARD'].mode()[0],inplace=True)
# C:\Users\ishaa\AppData\Local\Temp\ipykernel_7924\1962741249.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.to_csv('Working dataset.csv',index=False)
